# %%
# %matplotlib notebook
import numpy as np
import sympy as sp
from matplotlib import pyplot as plt
from sympy import MatMul

# %%
#x1=a*sp.cos(v_1*t/a)
#y1=a*sp.sin(v_1*t/a)
#x=sp.lambdify(t,x1)
#y=sp.lambdify(t,y1)
#ts=np.linspace(0,2*np.pi,100)
#plt.plot(x(ts),y(ts))

# %%
t,x,y,z,r,o=sp.symbols('t,x,y,z,r,o')
a=5
#u0=4*np.pi*10**-7
v1=1

# %%
Cil=sp.Matrix([[sp.cos(o),sp.sin(o),0],[-sp.sin(o),sp.cos(o),0],[0,0,1]])
#MatMul(Cil,rp)
Cart=sp.Matrix([[sp.cos(o),-sp.sin(o),0],[sp.sin(o),sp.cos(o),0],[0,0,1]])

# %%
r1=sp.Matrix([r,0,z])#Vectro de posicion cilindrico arbitrario
rp=sp.Matrix([a*sp.cos(v1*t/a),a*sp.sin(v1*t/a),0]) #Posicion en cartesianas de la particula
rpc=Cil*rp #Posicion en cartesianas

vrp=sp.diff(rpc,t)
R=r1-rpc

Bc=vrp.cross(R)/R.norm()**3
Bxyz=Cart*Bc
Bx=sp.lambdify([r,o,z,t],Bxyz[0])
By=sp.lambdify([r,o,z,t],Bxyz[1])
Bz=sp.lambdify([r,o,z,t],Bxyz[2])

rr=np.linspace(0,a*2,10)
phi=np.linspace(0,2*np.pi,18)
zz=np.linspace(-4,4,8)

R,P,Z=np.meshgrid(rr,phi,zz)
X=R*np.cos(P)
Y=R*np.sin(P)
ts=0
Bxx=Bx(R,P,Z,ts)
Byy=By(R,P,Z,ts)
Bzz=Bz(R,P,Z,ts)

fig = plt.figure(figsize=(10,10))
ax = plt.axes(projection='3d')

BB=np.sqrt(Bxx**2+Byy**2+Bzz**2)
tt=np.linspace(0,2*np.pi,100)
ax.scatter(a*np.cos(v1*ts/a),a*np.sin(v1*ts/a),0,color='blue')
ax.plot(a*np.cos(tt),a*np.sin(tt),0,color='red')
#################################################Campo vectorial###############################
ax.quiver(X,Y,Z,Bxx,Byy,Bzz,color='black')
#ax.quiver(X,Y,Z,Bxx/BB,Byy/BB,Bzz/BB,color='black')
#ax.quiver(zz*0,zz*0,zz,Bxx*0/BB,Byy*0/BB,Bz(0,0,zz,0)/Bz(0,0,zz,0),color='black')
plt.axis('equal')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="999.999985098839">

# %%
fig2=plt.figure()
th=np.linspace(0,100,1000)
plt.plot(th,np.sqrt(Bx(2*a,0,0,th)**2+By(2*a,0,0,th)**2+Bz(2*a,0,0,th)**2),color='black',label='|B|')
#plt.plot(th,Bx(2*a,0,0,th),label='Bx')
#plt.plot(th,By(2*a,0,0,th),label='By')
plt.plot(th,Bz(2*a,0,0,th),label='Bz')
plt.grid('on')
plt.legend()
plt.title('Campo magnetico B(2a,0,0) vs tiempo')
plt.ylabel('B(2a,0,0)')
plt.xlabel('Tiempo(s)')
#plt.axis('equal')
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">
# Text(0.5, 0, 'Tiempo(s)')

# %%
fig3=plt.figure()
plt.plot(tt,Bz(0,0,0,tt),label='Bz(r=0,phi=0,z=0) vs t')
plt.plot(tt,Bz(0,0,2,tt),label='Bz(r=0,phi=0,z=2) vs t')
plt.plot(tt,Bz(0,0,10,tt),label='Bz(r=0,phi=0,z=10) vs t')
plt.plot(tt,Bz(0,0,-5,tt),label='Bz(r=0,phi=0,z=-5) vs t')
plt.grid('on')
plt.title(' Bz en  eje z vs tiempo(s)')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
# Out:
# z*(sin(o)*sin(t/5) + cos(o)*cos(t/5))/(Abs(z)**2 + Abs(5*sin(o)*cos(t/5) - 5*sin(t/5)*cos(o))**2 + Abs(-r + 5*sin(o)*sin(t/5) + 5*cos(o)*cos(t/5))**2)**(3/2)

# %%
q1=1
q2=2*q1
v2=3*v1

r2=sp.Matrix([0,0,-v2*t])
vr2=sp.diff(r2,t)

F=q2*(vr2.cross(Bc))
F.subs(o,0).subs(r,0).subs(z,-v2*t)
# Out:
# Matrix([
# [-18*t*sin(t/5)/(9*Abs(t)**2 + 25*Abs(sin(t/5))**2 + 25*Abs(cos(t/5))**2)**(3/2)],
# [ 18*t*cos(t/5)/(9*Abs(t)**2 + 25*Abs(sin(t/5))**2 + 25*Abs(cos(t/5))**2)**(3/2)],
# [                                                                              0]])

# %%
r1=sp.Matrix([r,0,z])#Vectro de posicion cilindrico

R=r1-r2

Bc2=vr2.cross(R)/R.norm()**3
Bxyz2=Cart*Bc2
Bx2=sp.lambdify([r,o,z,t],Bxyz2[0])
By2=sp.lambdify([r,o,z,t],Bxyz2[1])
Bz2=sp.lambdify([r,o,z,t],Bxyz2[2])

rr=np.linspace(0,a*2,10)
phi=np.linspace(0,2*np.pi,18)
zz=np.linspace(-4,4,8)

R,P,Z=np.meshgrid(rr,phi,zz)
X=R*np.cos(P)
Y=R*np.sin(P)
ts=1.5
Bxx2=Bx2(R,P,Z,ts)
Byy2=By2(R,P,Z,ts)
Bzz2=Bz2(R,P,Z,ts)

fig = plt.figure(figsize=(10,10))
ax = plt.axes(projection='3d')

BB2=np.sqrt(Bxx2**2+Byy2**2+Bzz2**2)

tt=np.linspace(0,2*np.pi,100)
ax.scatter(0,0,-v2*ts,color='red')#Puntito
ax.plot(zz*0,zz*0,-v2*zz,color='blue')#Trayectoria
#ax.quiver(X,Y,Z,Bxx2,Byy2,Bzz2,color='black')
#ax.quiver(X,Y,Z,Bxx2/BB2,Byy2/BB2,Bzz2/BB2,color='black')

#ax.quiver(X[:,:,0],Y[:,:,0],Z[:,:,0],(Bxx2/BB2)[:,:,0],(Byy2/BB2)[:,:,0],(Bzz2/BB2)[:,:,0],color='black')

#ax.streamplot(X[:,:,0],Y[:,:,0],Z[:,:,0],(Bxx2/BB2)[:,:,0],(Byy2/BB2)[:,:,0],(Bzz2/BB2)[:,:,0])
ax.quiver(X,Y,Z,(Bxx2/BB2)+Bxx/BB,Byy2/BB2+Byy/BB,Bzz2/BB2+Bzz/BB,color='black')
#ax.quiver(X,Y,Z,Bxx2+Bxx,Byy2+Byy,Bzz2+Bzz,color='black')
plt.axis('equal')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="999.999985098839">
# C:\Users\Arif\AppData\Local\Temp\ipykernel_8268\89745252.py:37: RuntimeWarning: invalid value encountered in divide
#   ax.quiver(X,Y,Z,(Bxx2/BB2)+Bxx/BB,Byy2/BB2+Byy/BB,Bzz2/BB2+Bzz/BB,color='black')

# %%
F1=q1*(vrp.cross(Bc2))
F1.subs(r,a).subs(o,v1*t/a).subs(z,0)
# Out:
# Matrix([
# [0],
# [0],
# [0]])

# %%
Bc2
# Out:
# Matrix([
# [                                        0],
# [-3*r/(Abs(r)**2 + Abs(3*t + z)**2)**(3/2)],
# [                                        0]])

# %%
# Out:
# Matrix([
# [sin(o)*cos(t/5) - sin(t/5)*cos(o)],
# [sin(o)*sin(t/5) + cos(o)*cos(t/5)],
# [                                0]])
