# %%
from matplotlib import pyplot as plt
import sympy as sp
from sympy.plotting import plot

# %%
x=sp.symbols('x')
a=1/2
f=x*sp.exp(-a*x)

xp=sp.integrate(f,x)#+1/a**2
xpp=sp.integrate(xp)
plot(f,xp,xpp,show=True)
